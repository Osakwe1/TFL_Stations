# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# pd.set_option('display.float_format', lambda x: '%.5f' % x)
#pd.set_option('display.max_rows', None)

# %%
#Loading in TFL Station Exit & Entry Spreadsheet for 2017 
file_name =  '/Users/olisa/code/Osakwe1/Projects/TFL/AnnualisedEntryExit_2017.xlsx'
sheet =  'Annualised'
#Some Rows are skipped and irrelevant columns are dropped to standardize the DataFrame
df2017 = pd.read_excel(io=file_name, sheet_name=sheet, skiprows=6) 
df2017=df2017.drop(columns=['entries', 
                            'entries.1', 
                            'entries.2',
                            'Unnamed: 7',
                            'exits',
                            'exits.1',
                            'exits.2',
                            'Unnamed: 11']).round()
df2017
# Out:
#         Mode   NLC   ASC       Station                       Coverage  \
# 0         LU   500  ACTu    Acton Town           Station entry / exit
# 1         LU   502  ALDu       Aldgate           Station entry / exit
# 2         LU   503  ALEu  Aldgate East           Station entry / exit
# 3         LU   505  ALPu      Alperton           Station entry / exit
# 4         LU   506  AMEu      Amersham           Station entry / exit
# ..       ...   ...   ...           ...                            ...
# 434  TfLRail  6970  MYLr      Maryland           Station entry / exit
# 435  TfLRail  6886  RMFr       Romford  TfL Rail boarding / alighting
# 436  TfLRail  6893  SVKr   Seven Kings           Station entry / exit
# 437  TfLRail  6888  SNFr     Shenfield  TfL Rail boarding / alighting
# 438  TfLRail   719  SFDu     Stratford  TfL Rail boarding / alighting
#
#            Source          en/ex
# 0          Relate  5731527.00000
# 1          Relate  8459234.00000
# 2          Relate 13262408.00000
# 3          Relate  2896391.00000
# 4          Relate  2215502.00000
# ..            ...            ...
# 434  Manual Count  1283840.00000
# 435  Manual Count  7808711.00000
# 436      Gateline  3030081.00000
# 437  Manual Count  1724799.00000
# 438  Manual Count 27282075.00000
#
# [439 rows x 7 columns]

# %%
#Loading in TFL Station Exit & Entry Spreadsheet for 2020 
file_name =  '/Users/olisa/code/Osakwe1/Projects/TFL/AC2020_AnnualisedEntryExit.xlsx'
sheet =  'Annualised'
#Some Rows are skipped and irrelevant columns are dropped to standardize the DataFrame
df2020 = pd.read_excel(io=file_name, sheet_name=sheet, skiprows=6) 
df2020=df2020.drop(columns=['Entries', 
                    'Entries.1', 
                    'Entries.2', 
                    'Entries.3', 
                    'Exits', 
                    'Exits.1', 
                    'Exits.2', 
                    'Exits.3']).round()
df2020
# Out:
#     Mode   NLC   ASC                   Station                 Coverage  \
# 0     LU   719  SFDu                 Stratford     Station entry / exit
# 1     LU   635  LONu          London Bridge LU     Station entry / exit
# 2     LU   741  VICu               Victoria LU     Station entry / exit
# 3     LU   625  KXXu  King's Cross St. Pancras     Station entry / exit
# 4     LU   747  WLOu               Waterloo LU     Station entry / exit
# ..   ...   ...   ...                       ...                      ...
# 453  EZL  3151  TAPr                    Taplow     Station entry / exit
# 454  EZL  3155  TWYr                   Twyford     Station entry / exit
# 455   LO  5420  BAKr            Battersea Park  LO boarding / alighting
# 456   LU   781  HRFu    Heathrow Terminal 4 LU                      NaN
# 457  EZL  7091  HAFr    Heathrow Terminal 4 EL                      NaN
#
#         Source          En/Ex
# 0     Gateline 25071500.00000
# 1     Gateline 24721911.00000
# 2     Gateline 22954962.00000
# 3     Gateline 18837593.00000
# 4     Gateline 16621546.00000
# ..         ...            ...
# 453   Gateline    20878.00000
# 454   Gateline    13407.00000
# 455  Loadweigh    10748.00000
# 456        NaN            NaN
# 457        NaN            NaN
#
# [458 rows x 7 columns]

# %%
#Loading in TFL Station Exit & Entry Spreadsheet for 2021 
file_name =  '/Users/olisa/code/Osakwe1/Projects/TFL/AC2021_AnnualisedEntryExit.xlsx'
sheet =  'Annualised'
#Some Rows are skipped and irrelevant columns are dropped to standardize the DataFrame
#The 2021 DataFrame is expanded to include Trams, as well
df2021 = pd.read_excel(io=file_name, sheet_name=sheet, skiprows=6) 
df2021=df2021.drop(columns=['Entries', 
                    'Entries.1', 
                    'Entries.2', 
                    'Entries.3', 
                    'Exits', 
                    'Exits.1', 
                    'Exits.2', 
                    'Exits.3']).round()
df2021
# Out:
#     Mode   NLC   ASC             Station                    Coverage  \
# 0     LU   500  ACTu          Acton Town        Station entry / exit
# 1     LU   502  ALDu             Aldgate        Station entry / exit
# 2     LU   503  ALEu        Aldgate East        Station entry / exit
# 3     LU   505  ALPu            Alperton        Station entry / exit
# 4     LU   506  AMEu            Amersham        Station entry / exit
# ..   ...   ...   ...                 ...                         ...
# 494  TRM  9498  WPKt         Wandle Park  Trams boarding / alighting
# 495  TRM  9499  WLRt      Wellesley Road  Trams boarding / alighting
# 496  TRM  8776  WCRt  West Croydon Trams  Trams boarding / alighting
# 497  TRM  8777  WMBt     Wimbledon Trams  Trams boarding / alighting
# 498  TRM  8779  WDSt            Woodside  Trams boarding / alighting
#
#        Source         En/Ex
# 0    Gateline 2902697.00000
# 1    Gateline 3525128.00000
# 2    Gateline 5611130.00000
# 3    Gateline 1345253.00000
# 4    Gateline  946577.00000
# ..        ...           ...
# 494       APC  804251.00000
# 495       APC  389008.00000
# 496       APC 1514414.00000
# 497       APC 1843892.00000
# 498       APC  500843.00000
#
# [499 rows x 7 columns]

# %%
#The DataDrame contains 458 Counts of Stations but some stations contain  
df['Station'].count()
# Out:
# 458

# %%
df['Mode'].nunique()
# Out:
# 4

# %%
df['NLC'].nunique()
# Out:
# 426

# %%
df_grouped2017=df2017.groupby(['Station']).sum('en/ex').sort_values('en/ex', ascending=False).reset_index()
df_grouped2017
# Out:
#                       Station   NLC           en/ex
# 0                   Stratford  2876 111539219.00000
# 1    King's Cross St. Pancras   625  92620193.00000
# 2           Bank and Monument  1026  90922111.00000
# 3                 Waterloo LU   747  86887788.00000
# 4               Oxford Circus   669  79778619.00000
# ..                        ...   ...             ...
# 403                  Cheshunt  6814    453708.00000
# 404             Roding Valley   688    352989.00000
# 405              Emerson Park  7473    275227.00000
# 406            Battersea Park  5420     10383.00000
# 407              Custom House   887         0.00000
#
# [408 rows x 3 columns]

# %%
df_grouped2020=df2020.groupby(['Station']).sum('En/Ex').sort_values('En/Ex', ascending=False).reset_index()
df_grouped2020
# Out:
#                       Station   NLC          En/Ex
# 0                   Stratford  2876 53788483.00000
# 1            London Bridge LU   635 24721911.00000
# 2                 Victoria LU   741 22954962.00000
# 3                Canning Town  1768 21331852.00000
# 4    King's Cross St. Pancras   625 18837593.00000
# ..                        ...   ...            ...
# 421                    Taplow  3151    20878.00000
# 422                   Twyford  3155    13407.00000
# 423            Battersea Park  5420    10748.00000
# 424    Heathrow Terminal 4 EL  7091        0.00000
# 425    Heathrow Terminal 4 LU   781        0.00000
#
# [426 rows x 3 columns]

# %%
df_grouped2021=df2021.groupby(['Station']).sum('En/Ex').sort_values('En/Ex', ascending=False).reset_index()
df_grouped2021
# Out:
#                       Station   NLC          En/Ex
# 0                   Stratford  2876 63439192.00000
# 1    King's Cross St. Pancras   625 36734085.00000
# 2                 Victoria LU   741 33480926.00000
# 3               Oxford Circus   669 32863152.00000
# 4            London Bridge LU   635 30857082.00000
# ..                        ...   ...            ...
# 462               Coombe Lane  9464   132736.00000
# 463               Avenue Road  9444    75180.00000
# 464            Battersea Park  5420     6842.00000
# 465    Heathrow Terminal 4 EL  7091        0.00000
# 466    Heathrow Terminal 4 LU   781        0.00000
#
# [467 rows x 3 columns]

# %%
pd.merge(pd.merge(df_grouped2017,df_grouped2020,on='Station', how='outer'),df_grouped2021,on='Station', how='outer')
# Out:
#                       Station      NLC_x           en/ex      NLC_y  \
# 0                   Stratford 2876.00000 111539219.00000 2876.00000
# 1    King's Cross St. Pancras  625.00000  92620193.00000  625.00000
# 2           Bank and Monument 1026.00000  90922111.00000 1026.00000
# 3                 Waterloo LU  747.00000  86887788.00000  747.00000
# 4               Oxford Circus  669.00000  79778619.00000  669.00000
# ..                        ...        ...             ...        ...
# 462           Harrington Road        NaN             NaN        NaN
# 463           Beddington Lane        NaN             NaN        NaN
# 464            Birkbeck Trams        NaN             NaN        NaN
# 465               Coombe Lane        NaN             NaN        NaN
# 466               Avenue Road        NaN             NaN        NaN
#
#            En/Ex_x   NLC        En/Ex_y
# 0   53788483.00000  2876 63439192.00000
# 1   18837593.00000   625 36734085.00000
# 2   15625280.00000  1026 30132853.00000
# 3   16621546.00000   747 29868623.00000
# 4   14598777.00000   669 32863152.00000
# ..             ...   ...            ...
# 462            NaN  9475   206593.00000
# 463            NaN  9449   192204.00000
# 464            NaN  9454   174519.00000
# 465            NaN  9464   132736.00000
# 466            NaN  9444    75180.00000
#
# [467 rows x 7 columns]

# %%
df.loc[df['Station'] == 'Stratford']
# Out:
#     Mode  NLC   ASC    Station                       Coverage     Source  \
# 0     LU  719  SFDu  Stratford           Station entry / exit   Gateline
# 13    LO  719  SFDu  Stratford        LO boarding / alighting  Loadweigh
# 29   EZL  719  SFDu  Stratford  TfL Rail boarding / alighting     Scaled
# 429  DLR  719  SFDu  Stratford       DLR boarding / alighting        APC
#
#              En/Ex
# 0   25071500.00000
# 13  11480255.00000
# 29   8480044.00000
# 429  8756684.00000

# %%
df1 = pd.read_csv('Stations_20180921.csv')
df1.sample(5)
# Out:
#      FID  OBJECTID              NAME  EASTING  NORTHING       LINES  \
# 313  313        44         Greenford   514763    183928     Central
# 65    65       395  Liverpool Street   533094    181567         NaN
# 376  376       352      South Kenton   517316    187081         NaN
# 185  185       466      POPLAR - DLR   537701    180617         NaN
# 79    79        20     Holloway Road   530907    185450  Piccadilly
#
#                 NETWORK  Zone        x        y
# 313  London Underground     4 -0.34492 51.54209
# 65             TfL Rail     1 -0.08160 51.51684
# 376   London Overground     4 -0.30707 51.56990
# 185                 DLR     2 -0.01561 51.50720
# 79   London Underground     2 -0.11165 51.55225

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# %%
df1["Coordinates"] = list(zip(df1.EASTING, df1.NORTHING))
df1.head()
# Out:
#    FID  OBJECTID           NAME  EASTING  NORTHING             LINES  \
# 0    0        78         Temple   530959    180803  District, Circle
# 1    1        79    Blackfriars   531694    180893  District, Circle
# 2    2        80  Mansion House   532354    180932  District, Circle
# 3    3        81  Cannon Street   532611    180900  District, Circle
# 4    4        82       Monument   532912    180824  District, Circle
#
#               NETWORK  Zone         x          y       Coordinates
# 0  London Underground     1 -0.112644  51.510474  (530959, 180803)
# 1  London Underground     1 -0.102020  51.511114  (531694, 180893)
# 2  London Underground     1 -0.092495  51.511306  (532354, 180932)
# 3  London Underground     1 -0.088801  51.510963  (532611, 180900)
# 4  London Underground     1 -0.084502  51.510209  (532912, 180824)

# %%
df1["Coordinates"] = df1["Coordinates"].apply(Point)
df1.head()
# Out:
#    FID  OBJECTID           NAME  EASTING  NORTHING             LINES  \
# 0    0        78         Temple   530959    180803  District, Circle
# 1    1        79    Blackfriars   531694    180893  District, Circle
# 2    2        80  Mansion House   532354    180932  District, Circle
# 3    3        81  Cannon Street   532611    180900  District, Circle
# 4    4        82       Monument   532912    180824  District, Circle
#
#               NETWORK  Zone         x          y            Coordinates
# 0  London Underground     1 -0.112644  51.510474  POINT (530959 180803)
# 1  London Underground     1 -0.102020  51.511114  POINT (531694 180893)
# 2  London Underground     1 -0.092495  51.511306  POINT (532354 180932)
# 3  London Underground     1 -0.088801  51.510963  POINT (532611 180900)
# 4  London Underground     1 -0.084502  51.510209  POINT (532912 180824)

# %%
gdf = gpd.GeoDataFrame(df1, geometry="Coordinates")
gdf.head()
# Out:
#    FID  OBJECTID           NAME  EASTING  NORTHING             LINES  \
# 0    0        78         Temple   530959    180803  District, Circle
# 1    1        79    Blackfriars   531694    180893  District, Circle
# 2    2        80  Mansion House   532354    180932  District, Circle
# 3    3        81  Cannon Street   532611    180900  District, Circle
# 4    4        82       Monument   532912    180824  District, Circle
#
#               NETWORK  Zone         x          y  \
# 0  London Underground     1 -0.112644  51.510474
# 1  London Underground     1 -0.102020  51.511114
# 2  London Underground     1 -0.092495  51.511306
# 3  London Underground     1 -0.088801  51.510963
# 4  London Underground     1 -0.084502  51.510209
#
#                      Coordinates
# 0  POINT (530959.000 180803.000)
# 1  POINT (531694.000 180893.000)
# 2  POINT (532354.000 180932.000)
# 3  POINT (532611.000 180900.000)
# 4  POINT (532912.000 180824.000)

# %%
df1["NAME"]
# Out:
# 0                  Temple
# 1             Blackfriars
# 2           Mansion House
# 3           Cannon Street
# 4                Monument
#               ...
# 474        Crystal Palace
# 475             Brentwood
# 476             Shenfield
# 477       Woodgrange Park
# 478    Willesden Junction
# Name: NAME, Length: 479, dtype: object

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FID          479 non-null    int64
#  1   OBJECTID     479 non-null    int64
#  2   NAME         479 non-null    object
#  3   EASTING      479 non-null    int64
#  4   NORTHING     479 non-null    int64
#  5   LINES        271 non-null    object
#  6   NETWORK      479 non-null    object
#  7   Zone         479 non-null    int64
#  8   x            479 non-null    float64
#  9   y            479 non-null    float64
#  10  Coordinates  479 non-null    geometry
# dtypes: float64(2), geometry(1), int64(5), object(3)
# memory usage: 41.3+ KB

# %%
ldn_df = gpd.read_file("London-wards-2018/London-wards-2018_ESRI/London_Ward_CityMerged.shp")
ldn_df.sample(3)
# Out:
#                           NAME   GSS_CODE       DISTRICT  LAGSSCODE  HECTARES  \
# 519  St. Katharine's & Wapping  E05009330  Tower Hamlets  E09000030   149.089
# 109                  Upminster  E05000323       Havering  E09000016  2253.736
# 539                Clerkenwell  E05000370      Islington  E09000019    93.263
#
#      NONLD_AREA                                           geometry
# 519      42.323  POLYGON ((533669.796 180263.399, 533604.702 18...
# 109       0.000  POLYGON ((553840.201 184909.400, 553848.800 18...
# 539       0.000  POLYGON ((530510.000 183011.603, 530546.798 18...

# %%
fig, gax = plt.subplots(figsize=(18, 18))
ldn_df.plot(ax=gax, edgecolor="black", color="white")
gdf.plot(ax=gax, color='blue', alpha = 0.5)
plt.show()
